# %% [markdown]
# # EDA Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('/kaggle/input/melbourne-housing-snapshot/melb_data.csv')
print(data.head())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
#Check for miising data
print(data.isnull().sum())

#visualize missing data
plt.figure(figsize=(10,6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.show()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
#Handle missing and duplicate data
data.dropna(inplace=True)

data.drop_duplicates(inplace=True)

#Check for miising data
print(data.isnull().sum())
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
bins = [0, 500000, 1000000, 1500000, 2000000, np.inf] 
labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

data['PriceCategory'] = pd.cut(data['Price'], bins=bins, labels=labels)

# Check the result
data.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
# 6  7/05/2016       2.5    3067.0  ...  0.0     245.0         210.0     1910.0
# 7  8/10/2016       2.5    3067.0  ...  2.0     256.0         107.0     1890.0
#
#    CouncilArea  Lattitude Longtitude             Regionname  Propertycount  \
# ...

# %%
from datetime import date
date.today().year
data['House_Age']= date.today().year - data['YearBuilt']
data.head()
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 4  Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 6  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 1  4/02/2016       2.5    3067.0  ...     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...     134.0         150.0     1900.0
# 4  4/06/2016       2.5    3067.0  ...     120.0         142.0     2014.0
# 6  7/05/2016       2.5    3067.0  ...     245.0         210.0     1910.0
# 7  8/10/2016       2.5    3067.0  ...     256.0         107.0     1890.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'Date', 'CouncilArea',
#        'Regionname'],
#       dtype='object')
# Numerical Variables:
# ['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount', 'House_Age']

# %%
palette = sns.color_palette("husl", 8)

for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    
    plt.figure(figsize=(16, 5))
    
    # Histogram plot
    plt.subplot(1, 2, 1)
    sns.histplot(data[col], bins=30, kde=True, color=palette[0], edgecolor='black')
    plt.title(f'{col} Distribution', fontsize=14)
    plt.xlabel(col)
    plt.ylabel('Count')
    
    # Box plot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col], color=palette[2])
    plt.title(f'{col} Box Plot', fontsize=14)
    
    plt.tight_layout()
    plt.show()
# Out:
# Rooms
# Skew : 0.33
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Price
# Skew : 2.48
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Distance
# Skew : 1.76
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Postcode
# Skew : 3.89
# ...

# %%
# Loop through categorical columns
for col in cat_cols:
    plt.figure(figsize=(12, 6))  # Set figure size
    
    # Count plot
    sns.countplot(data=data, x=col, palette='husl', order=data[col].value_counts().index)
    
    # Add titles and labels
    plt.title(f'{col} Frequency Distribution', fontsize=16)
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=45)  # Rotate x labels for better readability
    
    plt.show()

# %%
# Box plot for Price vs. Suburb
plt.figure(figsize=(15, 6))
sns.boxplot(x='Suburb', y='Price', data=data, palette='husl')
plt.title('Price Distribution by Suburb', fontsize=16)
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.ylabel('Price', fontsize=14)
plt.xlabel('Suburb', fontsize=14)
plt.show()

# Count plot for Type and Method
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='Type', hue='Method', palette='husl')
plt.title('Count of Property Types by Sale Method', fontsize=16)
plt.ylabel('Count', fontsize=14)
plt.xlabel('Property Type', fontsize=14)
plt.legend(title='Sale Method')
plt.show()

# Scatter plot for Price vs. Rooms
plt.figure(figsize=(12, 6))
sns.stripplot(x='Rooms', y='Price', data=data, jitter=True, palette='husl')
plt.title('Price vs. Number of Rooms', fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Number of Rooms', fontsize=14)
plt.show()
# Out:
# /tmp/ipykernel_17/3409721751.py:21: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Rooms', y='Price', data=data, jitter=True, palette='husl')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
# Calculate the correlation matrix for numerical variables
correlation_matrix = data[num_cols].corr()

# Set up the matplotlib figure
plt.figure(figsize=(14, 10))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True, 
            linewidths=0.5, linecolor='gray')

# Add title and labels
plt.title('Correlation Heatmap of Numerical Variables', fontsize=18)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)   # Keep y-axis labels horizontal
plt.show()
